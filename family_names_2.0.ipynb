# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/parcel_grouped.csv')

# %%
df
# Out:
#       Unnamed: 0      area                                          1748Owner  \
# 0              0    80.042  Padre Felippo Rota per eredi della quondam Dom...
# 1              1   700.702                              Giovanni Battista Zen
# 2              2   105.043                        Vincenzo e fratelli Grimani
# 3              3   161.716                                       Ferigo Calbo
# 4              4   993.866                        Zuanne et Fratelli Toderini
# ...          ...       ...                                                ...
# 1399        1399   276.977                                     Fantin Dandolo
# 1400        1400   468.138                                  Francesco Dandolo
# 1401        1401    87.046                                     Carlo Castelli
# 1402        1402    84.928                                     Zorzi Morosini
# 1403        1403  1900.302                          Alvise, e Fratelli Civran
#
#                                               1808Owner english_cata  \
# 0            BELLI Angelo Livellario di Lorenzo Tiepolo      housing
# 1                             ZEN Antonio q. Sebastiano      housing
# 2                         BRAGADINI Giovanni q. Gaspare      storage
# 3                          CROTTA Lucrezia vedova CALVO      housing
# 4     TODARINI Luigi q. Giuseppe, e Ferdinando q. Te...      housing
# ...                                                 ...          ...
# 1399                        DANDOLO Francesco q.m Marco      housing
# 1400                          PIZONI Giuseppe q.m .....      housing
# 1401                  QUERINI CASTELLI Elena q.m ......      housing
# 1402  MOROSINI Giorgio, e Giovanni Fratelli q.m Giorgio      housing
# 1403           CIVRAN CONTARINI Catterina q.m Benedetto      housing
#
#      english_cada  parcel_number  change
# 0            shop              3       1
# 1         housing              5       0
# 2         housing              8       1
# 3            shop              9       1
# 4            shop             11       1
# ...           ...            ...     ...
# 1399      housing          11911       0
# 1400      housing          11912       0
# 1401      housing          11915       0
# 1402      housing          11918       0
# 1403      housing          11919       0
#
# [1404 rows x 8 columns]

# %%
list_family_names = pd.read_csv('data/')
family_name_options = list_family_names['family'].values

# %%
# we will use a fuzzy ratio to extract the name
from fuzzywuzzy import fuzz, process

top_3_names = catastici['entryOwnerText_l'].apply(lambda x: process.extract(x,family_name_options, scorer=fuzz.token_set_ratio, limit = 3))
