# %%
import pandas as pd

# %%
catastici_df = pd.read_csv('data\catastici_1741.csv')

# %%
catastici_df
# Out:
#         id  entryId                                     entryOwnerText  \
# 0        0    205.0     Scola di Santa Maria e San Cristofolo all'orto
# 1        1    206.0     Scola di Santa Maria e San Cristofolo all'orto
# 2        2    207.0                                Alessandro Buffetti
# 3        3    207.0                                Alessandro Buffetti
# 4        4    207.0                                Alessandro Buffetti
# ...    ...      ...                                                ...
# 9717  9717    105.0                   Francesco e Zuanne fratelli Moro
# 9718  9718    105.0                   Francesco e Zuanne fratelli Moro
# 9719  9719    105.0                   Francesco e Zuanne fratelli Moro
# 9720  9720    166.0  Lugrezia Porta Guazzo Zia de Marchio e Fratell...
# 9721  9721    104.0                            Moniche di Santa Chiara
#
#           entryTenantText           entryCategoryText  rent  \
# 0          Simon Bernardi                        Casa  34.0
# 1           Giacomo Aghen                        Casa  40.0
# 2     Cristofolo Fianello    Casa, primo appartamento  20.0
# 3     Per uso del padrone  Casa, secondo appartamento   NaN
# 4             Inaffittato    Casa, terzo appartamento  30.0
# ...                   ...                         ...   ...
# 9717      Domenico Fabris      Casa in cinque fitanze  14.0
# 9718   Domenica Capellari      Casa in cinque fitanze   6.0
# 9719         Adamo Fachin      Casa in cinque fitanze  10.0
# 9720                  NaN  Per altra porzione di Casa  21.0
# 9721       Oliva Fioretti        Casa, secondo solaro  60.0
#
#       cadaster1808Correspondance               toponym entryCategories  \
# 0                         2030.0       Calle Galliazza     ['housing']
# 1                         2030.0       Calle Galliazza     ['housing']
# 2                            NaN       Calle Galliazza     ['housing']
# 3                            NaN       Calle Galliazza     ['housing']
# 4                            NaN       Calle Galliazza     ['housing']
# ...                          ...                   ...             ...
# 9717                     10105.0  Calletta della Torre     ['housing']
# 9718                     10105.0  Calletta della Torre     ['housing']
# 9719                     10105.0  Calletta della Torre     ['housing']
# 9720                       512.0   Calle di Ca' Corner     ['housing']
# 9721                     10107.0  Calletta della Torre     ['housing']
#
#       cadaster1808ClosestParcel                    position
# 0                          2030  [12.33676417, 45.43740331]
# 1                          2030  [12.33678175, 45.43739419]
# 2                         13268  [12.33680766, 45.43745093]
# 3                         13268   [12.3368313, 45.43744348]
# 4                         13268  [12.33685662, 45.43743407]
# ...                         ...                         ...
# 9717                      10105   [12.33397622, 45.4393669]
# 9718                      10105   [12.3339705, 45.43936174]
# 9719                      10105   [12.33396503, 45.4393554]
# 9720                        512  [12.32959686, 45.43466271]
# 9721                      10107  [12.33391876, 45.43938881]
#
# [9722 rows x 11 columns]

# %%
catastici_df.rent.describe()
# Out:
# count    8735.000000
# mean       43.301317
# std        49.240012
# min         1.000000
# 25%        15.000000
# 50%        30.000000
# 75%        52.000000
# max       835.000000
# Name: rent, dtype: float64

# %%
catastici_df.groupby('entryOwnerText')['id'].count().sort_values(ascending=False).head(20)
# Out:
# entryOwnerText
# Scola di San Rocco                         84
# Capitolo di San Moisè                      66
# Signori Canonici di San Salvatore          50
# Scola della Misericordia                   48
# Francesco Foscari                          46
# Michiel Morosini                           46
# Reverendi Padri di San Giorgio Maggiore    44
# Monastero di San Zaccaria                  40
# Zuanne Pasqualigo                          36
# Marc'Antonio Grimani                       32
# Marin Bernardo                             31
# Monastero di San Maffio di Mazorbo         27
# Monastero di San Lorenzo                   26
# Marc'Antonio Barbarigo                     26
# Ferigo Calbo                               25
# Monastero dell'Umiltà                      25
# Scola di San Marco                         25
# Clero di Venezia                           24
# Antonio Venier                             24
# Giovanni Maria Raspi                       24
# Name: id, dtype: int64

# %%
catastici_df.groupby('entryTenantText')['id'].count().sort_values(ascending=False).head(20)
# Out:
# entryTenantText
# Bortolo Usabelli          16
# Francesco Zancarelli      14
# Inaffittato               12
# Antonio Millesi           11
# Zuanne Astori             11
# Paolo Petregali Pistor    11
# vuota                     10
# Antonio Calvi              9
# Antonio Venturini          9
# Inaffittata                9
# Antonio Rossi              9
# Antonio Scolari            9
# Antonio Caminer            8
# Iseppo Snaider             8
# Bortolo Mora               8
# Lodovico Manin             8
# Marc'Antonio Capelan       8
# Sachi Macon                8
# Giacomo Ferretti           7
# Gaetano Saon               7
# Name: id, dtype: int64

# %%
catastici_df.entryCategories.value_counts()
# Out:
# ['housing']                              4021
# ['shop']                                 1753
# ['housing', 'storage']                   1375
# ['housing', 'shop']                       932
# ['storage']                               702
# ['shop', 'storage']                       272
# []                                        161
# ['transport']                             141
# ['housing', 'shop', 'storage']             88
# ['administration']                         49
# ['hospitality']                            41
# ['palace']                                 31
# ['housing', 'hospitality']                 26
# ['guild']                                  19
# ['shop', 'administration']                 16
# ['religious']                              10
# ['shop', 'hospitality']                     9
# ['housing', 'entertainment']                8
# ['entertainment']                           8
# ['housing', 'guild']                        5
# ['storage', 'hospitality']                  5
# ['storage', 'palace']                       5
# ['housing', 'palace']                       4
# ['housing', 'storage', 'garden']            4
# ['healthcare']                              4
# ['housing', 'administration']               4
# ['housing', 'storage', 'hospitality']       4
# ['religious', 'guild']                      3
# ['housing', 'garden']                       3
# ['shop', 'storage', 'administration']       2
# ['shop', 'garden']                          2
# ['storage', 'religious']                    2
# ['housing', 'shop', 'hospitality']          2
# ['shop', 'entertainment']                   1
# ['housing', 'religious']                    1
# ['housing', 'shop', 'administration']       1
# ['storage', 'guild']                        1
# ['palace', 'entertainment']                 1
# ['shop', 'palace']                          1
# ['storage', 'entertainment']                1
# ['housing', 'shop', 'garden']               1
# ['storage', 'palace', 'garden']             1
# ['housing', 'storage', 'guild']             1
# ['storage', 'administration']               1
# Name: entryCategories, dtype: int64

# %%
catastici_df.groupby(["entryOwnerText","entryTenantText"])["id"].count().sort_values()
# Out:
# entryOwnerText                             entryTenantText
# ... Vedova Lunella                         Vita Silva            1
# Nobil Homo Ser Paolo, e Fratelli Baglioni  Bortola da Cadeste    1
#                                            Anzolo Gaia           1
#                                            Anzola Melisi         1
#                                            Andrea Armano         1
#                                                                 ..
# Fratelli Vendramin                         Zuanne Curnis         3
# Zorzi Morosini                             Anzola Benetella      3
# Antonio Venier                             Antonio Spadon        4
# Giovanni Giacomo Hertz                     Inaffittato           5
# Teresa Campagnara                          Vuota                 6
# Name: id, Length: 8667, dtype: int64

# %%
catastici_df.groupby(['entryOwnerText', 'entryCategories'])['id'].count().sort_values(ascending=False).head(20)
# Out:
# entryOwnerText                           entryCategories
# Scola di San Rocco                       ['housing']               47
# Capitolo di San Moisè                    ['housing', 'storage']    29
# Francesco Foscari                        ['housing', 'storage']    25
# Signori Canonici di San Salvatore        ['housing']               25
# Reverendi Padri di San Giorgio Maggiore  ['housing', 'shop']       20
# Giovanni Maria Raspi                     ['shop']                  20
# Monastero di San Lorenzo                 ['housing']               19
# Michiel Morosini                         ['housing']               19
# Scola della Misericordia                 ['shop']                  19
# Marin Bernardo                           ['housing']               18
# Zuanne Pasqualigo                        ['housing']               18
# non si sa di più                         ['storage']               17
# Alberto Astori q. Giovanni Maria         ['housing', 'storage']    16
# Marc'Antonio Grimani                     ['housing', 'storage']    16
# Reverendi Padri di San Giorgio Maggiore  ['shop']                  16
# Conte Cesare e nipoti Piovene            ['housing', 'storage']    16
# Scola di San Rocco                       ['housing', 'storage']    16
# Giovanni Giacomo Hertz                   ['housing']               16
# Reverende Monache di S. Cosmo            ['housing']               15
# Monastero di San Maffio di Mazorbo       ['housing', 'storage']    15
# Name: id, dtype: int64
