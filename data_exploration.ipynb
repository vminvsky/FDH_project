# %%
import pandas as pd 
import gzip

# %%
import os
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'cadaster_1808_geometries_dump.sql.gz',
#  'catastici.json.gz',
#  'catastici_geometries_dump.sql.gz',
#  'data_exploration.ipynb',
#  'hannah.txt',
#  'sommarioni.json.gz']

# %%
catastici = gzip.open('catastici.json.gz').read()
catastici = a.decode("utf-8")
catastici_df = pd.read_json(catastici)

sommarioni = gzip.open('sommarioni.json.gz').read()
cadaster = a.decode("utf-8")
cadaster_df = pd.read_json(cadaster)

# %%
# Out:
#           id sestiere parcelNumber subParcelNumber     correspondanceAustrian  \
# 0          0      NSM            1            None          ASM 2121 ASM 2122
# 1          1      NSM            2               1                   ASM 2124
# 2          2      NSM            2               2                   ASM 2124
# 3          3      NSM            3               1                   ASM 2123
# 4          4      NSM            3               2                   ASM 2123
# ...      ...      ...          ...             ...                        ...
# 23423  23423      NSM            V            None  non esiste corrispondente
# 23424  23424      NSM            X            None                   ASM 2411
# 23425  23425      NSM           XY            None          ASM 2411 ASM 2412
# 23426  23426      NSM            Y            None          ASM 2411 ASM 2412
# 23427  23427      NSM            Z            None                   ASM 2413
#
#            correspondanceItalian                        toponym houseNumber  \
# 0            AISM 2121 AISM 2122  SM - Parrocchia di S. Fantino   3205;3206
# 1                      AISM 2124  SM - Parrocchia di S. Fantino        3207
# 2                      AISM 2124  SM - Parrocchia di S. Fantino        None
# 3                      AISM 2123  SM - Parrocchia di S. Fantino        3208
# 4                      AISM 2123  SM - Parrocchia di S. Fantino        3209
# ...                          ...                            ...         ...
# 23423  non esiste corrispondente  SM - Parrocchia di S. Samuele        None
# 23424                  AISM 2411  SM - Parrocchia di S. Samuele        2501
# 23425        AISM 2411 AISM 2412  SM - Parrocchia di S. Samuele        2501
# 23426        AISM 2411 AISM 2412  SM - Parrocchia di S. Samuele        2501
# 23427                   ASM 2413  SM - Parrocchia di S. Samuele        2501
#
#                                          parcelOwnerText  \
# 0                        PAGANI - Concorso de' creditori
# 1                             TIEPOLO Gerolamo q. Almorò
# 2      PAGANI - Concorso come sopra al N° 1 [de' cred...
# 3             BELLI Angelo Livellario di Lorenzo Tiepolo
# 4                              TIEPOLO Lorenzo q. Almorò
# ...                                                  ...
# 23423                         PIAZZA detta di S. Samuele
# 23424      DEMANIO, e per esso il Ministero dell'Interno
# 23425  REGIO Conservatorio suddetto [S. Rocco e S. Ma...
# 23426  Suddetto o[DEMANIO, e per esso il Ministero de...
# 23427  Chiesa sotto il titolo di S. Rocco spettante a...
#
#                                       parcelCategoryText  parcelCategories  \
# 0                                         Casa d'affitto            [CASA]
# 1                                         Casa d'affitto            [CASA]
# 2                                         Casa d'affitto            [CASA]
# 3                            Bottega unica a proprio uso         [BOTTEGA]
# 4                                    Superiori d'affitto                []
# ...                                                  ...               ...
# 23423                                                  -                []
# 23424  Casa ad uso del Regio Conservatorio di S. Rocc...            [CASA]
# 23425                                          Monastero       [MONASTERO]
# 23426                                    Locale suddetto          [LOCALE]
# 23427                      Chiesa e locali sacri annessi  [CHIESA, LOCALE]
#
#       parcelOwnershipType      area  \
# 0               [AFFITTO]   608.117
# 1               [AFFITTO]   540.546
# 2               [AFFITTO]   540.546
# 3               [PROPRIO]    80.042
# 4               [AFFITTO]    80.042
# ...                   ...       ...
# 23423                  []       NaN
# 23424                  []   767.036
# 23425                  []       NaN
# 23426                  []  2552.856
# 23427                  []   940.908
#
#                                                   bounds
# 0      [[12.334122, 45.433708], [12.3348277, 45.43387...
# 1      [[12.334480899999999, 45.4337119], [12.3348348...
# 2      [[12.334480899999999, 45.4337119], [12.3348348...
# 3      [[12.3341454, 45.4336382], [12.334232, 45.43372]]
# 4      [[12.3341454, 45.4336382], [12.334232, 45.43372]]
# ...                                                  ...
# 23423                                               None
# 23424  [[12.3294436, 45.4334037], [12.3297769, 45.433...
# 23425                                               None
# 23426  [[12.3295519, 45.4333128], [12.3302745, 45.433...
# 23427  [[12.3296863, 45.4337015], [12.3301199, 45.434...
#
# [23428 rows x 14 columns]
